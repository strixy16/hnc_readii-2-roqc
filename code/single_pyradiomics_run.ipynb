# %%
import os
import collections
import SimpleITK as sitk
import numpy 
import six
import radiomics
from radiomics import firstorder, glcm, imageoperations, shape, glrlm, glszm, ngtdm, gldm

# %%
from imgtools.io import read_dicom_series
from readii.loaders import loadSegmentation
from readii.image_processing import flattenImage, alignImages, displayImageSlice, displayCTSegOverlay, getCroppedImages, getROIVoxelLabel, getROICenterCoords

# %% [markdown]
# # Load image data

# %%
# RADCRE-2012
ctDirPath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-2012/12-26-2001-NA-Research HNC Planning CT-39063/3.000000-Helical Axial-26282"
segFilePath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-2012/12-26-2001-NA-Research HNC Planning CT-39063/1.000000-NA-03155/1-1.dcm"

# %%
# RADCURE-3716
ctDirPath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-3716/20091006-Research HNC Planning CT-1.3.6.1.4.1.14519.5.2.1.159479891309173287983489538813569798675/3-Neck 2.0 CE-1.3.6.1.4.1.14519.5.2.1.303618333208483957981299429120448318183"
segFilePath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-3716/20091006-Research HNC Planning CT-1.3.6.1.4.1.14519.5.2.1.159479891309173287983489538813569798675/1-UnknownSeriesDescription-1.3.6.1.4.1.14519.5.2.1.53689980185072466582338154816320570464/1.3.6.1.4.1.14519.5.2.1.196814539827040265136159678638398372874.dcm"

# %%
# RADCURE-2818
segFilePath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-2818/20050706-Research HNC Planning CT-1.3.6.1.4.1.14519.5.2.1.32217992229678458029795766308716011483/1-UnknownSeriesDescription-1.3.6.1.4.1.14519.5.2.1.140290746105280466409401562789091483595/1.3.6.1.4.1.14519.5.2.1.242324221082044849247326651271356162325.dcm"
ctDirPath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-2818/20050706-Research HNC Planning CT-1.3.6.1.4.1.14519.5.2.1.32217992229678458029795766308716011483/2-Neck 2.0 CE-1.3.6.1.4.1.14519.5.2.1.309190676350470239537900264663032220893"

# %%
#RADCURE-2840
ctDirPath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-2840/20050816-Research HNC Planning CT-1.3.6.1.4.1.14519.5.2.1.287491432052519970379240880654397710367/2-Neck 2.0 CE-1.3.6.1.4.1.14519.5.2.1.55419138121179541338800071683548264399"
segFilePath = "/Users/katyscott/Documents/HNC Project/data/error_images/RADCURE/RADCURE-2840/20050816-Research HNC Planning CT-1.3.6.1.4.1.14519.5.2.1.287491432052519970379240880654397710367/1-UnknownSeriesDescription-1.3.6.1.4.1.14519.5.2.1.303274724757270970302406387115992451078/1.3.6.1.4.1.14519.5.2.1.75523572134527947195118599778613464026.dcm"

# %%
ctImage = read_dicom_series(ctDirPath)
segImages = loadSegmentation(segImagePath=segFilePath,
                             modality='RTSTRUCT',
                             baseImageDirPath=ctDirPath,
                             roiNames='GTVp.*')
# Out:
# labels: {'GTVp': 0}

# %%
roiLabel = list(segImages.keys())[0]
roiImage = segImages[roiLabel]

# %%
print("CT dimensions: ", ctImage.GetSize())
print("Segmentation dimensions: ", roiImage.GetSize())
# Out:
# CT dimensions:  (512, 512, 178)
# Segmentation dimensions:  (512, 512, 178)

# %%
roiMask = alignImages(ctImage, roiImage)

# %%
segmentationLabel: int = getROIVoxelLabel(roiMask)

# %% [markdown]
# # Make Negative Control

# %%
from readii.negative_controls import *
import numpy as np

randomSeed = 10

# %%
fullImgCenterCoords = getROICenterCoords(roiMask)
print(fullImgCenterCoords)

# %%
negativeControlType = "randomized" 
negativeControlRegion = "full"

ctImage = applyNegativeControl(baseImage = ctImage, 
                               negativeControlType = negativeControlType, 
                               negativeControlRegion = negativeControlRegion, 
                               roiMask = roiMask, 
                               randomSeed = randomSeed)

# %% [markdown]
# # PyRadiomics Settings Setup

# %%
settings = {}
settings['binWidth'] = 25
settings['resampledPixelSpacing'] = [1., 1., 1.]
settings['interpolator'] = 'sitkBSpline'

# %%
# Resample if necessary
interpolator = settings.get('interpolator')
resampledPixelSpacing = settings.get('resampledPixelSpacing')
if interpolator is not None and resampledPixelSpacing is not None:
  ctImage, roiMask = imageoperations.resampleImage(ctImage, roiMask, **settings)

# %%
segBoundingBox, correctedROIMask = imageoperations.checkMask(ctImage, roiMask, label = segmentationLabel)
    
# Update the ROI image if a correction was generated by checkMask
if correctedROIMask is not None:
    roiMask = correctedROIMask

# Crop the image and mask to a bounding box around the mask to reduce volume size to process
croppedCT, croppedROIMask = imageoperations.cropToTumorMask(ctImage, roiMask, segBoundingBox)

# %%
croppedCT.GetSize()

# %%
negativeControlType = "randomized_sampled_non_roi"

croppedCT = applyNegativeControl(negativeControlType, croppedCT, croppedROIMask, 
                               roiLabel, randomSeed)

# %% [markdown]
# # Calculate Shape Features

# %%
shapeFeatures = shape.RadiomicsShape(croppedCT, croppedROIMask, **settings)

# Set the features to be calculated
# shapeFeatures.enableFeatureByName('MeshVolume', True)
shapeFeatures.enableAllFeatures()

# %%
# Calculate the features and print(out result)
print('Calculating shape features...',)
result = shapeFeatures.execute()
print('done')

print('Calculated shape features: ')
for (key, val) in six.iteritems(result):
  print('  ', key, ':', val)

# %% [markdown]
# # Calculate GLCM Features

# %%
radiomics.setVerbosity(10)

# %%
glcmFeatures = glcm.RadiomicsGLCM(croppedCT, croppedROIMask, **settings)

# Set the features to be calculated
# glcmFeatures.enableFeatureByName('MCC', True)
glcmFeatures.enableAllFeatures()

# %%
# Calculate the features and print(out result)
print('Calculating GLCM features...',)
result = glcmFeatures.execute()
print('done')

print('Calculated GLCM features: ')
for (key, val) in six.iteritems(result):
  print('  ', key, ':', val)

# %% [markdown]
# # Wavelet filtering

# %%
radiomics.setVerbosity(10)

# %%
waveletFeatures = {}

for decompositionImage, decompositionName, inputSettings in imageoperations.getWaveletImage(ctImage, roiMask):

    # if decompositionName == "wavelet-HLL":
    decompositionImage, croppedMask = imageoperations.cropToTumorMask(decompositionImage, roiMask, segBoundingBox)

    # waveletFirstOrderFeaturs = firstorder.RadiomicsFirstOrder(decompositionImage, croppedMask, **inputSettings)
    # waveletFirstOrderFeaturs.enableAllFeatures()

    # print('Calculate firstorder features with ', decompositionName)
    # waveletFeatures[decompositionName] = waveletFirstOrderFeaturs.execute()

    # waveletGLSZMFeatures = glszm.RadiomicsGLSZM(decompositionImage, croppedMask, **inputSettings)
    # waveletGLSZMFeatures.enableAllFeatures()

    # waveletNGTDMFeatures = ngtdm.RadiomicsNGTDM(decompositionImage, croppedMask, **inputSettings)
    # waveletNGTDMFeatures.enableAllFeatures()

    # waveletGLDMFeatures = gldm.RadiomicsGLDM(decompositionImage, croppedMask, **inputSettings)
    # waveletGLDMFeatures.enableAllFeatures()
    
    waveletGLCMFeatures = glcm.RadiomicsGLCM(decompositionImage, croppedMask, **inputSettings)
    waveletGLCMFeatures.disableAllFeatures()
    waveletGLCMFeatures.enableFeatureByName("MCC")
    # waveletGLCMFeatures.enableAllFeatures()

    print('Calculate features with ', decompositionName)
    waveletFeatures[decompositionName] = waveletGLCMFeatures.execute()

# %%
waveletFeatures['wavelet-HLL']

# %% [markdown]
# # Using READII

# %%
radiomics.setVerbosity(10)

# %%
from readii.feature_extraction import singleRadiomicFeatureExtraction

# pyradiomicsParamFilePath = "/Users/katyscott/Documents/readii/src/readii/data/default_pyradiomics.yaml"
pyradiomicsParamFilePath = "/Users/katyscott/Documents/HNC Project/scripts/hnc_readii-2-roqc/config/no_wavelet_pyradiomics.yaml"
# pyradiomicsParamFilePath = "/Users/katyscott/Documents/HNC Project/scripts/hnc_readii-2-roqc/config/original_and_wavelet_pyradiomics.yaml"
radiomicFeatures = singleRadiomicFeatureExtraction(ctImage, roiMask, pyradiomicsParamFilePath, randomSeed=10)
# Out:
# Checking mask with label 1
# Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# Cropping to size [56 71 22]
# Loading parameter file /Users/katyscott/Documents/HNC Project/scripts/hnc_readii-2-roqc/config/no_wavelet_pyradiomics.yaml
# Parameters parsed, input is valid.
# Applying settings
# Enabled image types: {'Original': {}, 'Square': {}, 'SquareRoot': {}, 'Logarithm': {}, 'Exponential': {}, 'Gradient': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Settings: {'binWidth': 25, 'resampledPixelSpacing': [1.0, 1.0, 1.0]}
# Calculating features with label: 1
# Enabled images types: {'Original': {}, 'Square': {}, 'SquareRoot': {}, 'Logarithm': {}, 'Exponential': {}, 'Gradient': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.0, 1.0, 1.0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25}
# Loading image and mask
# Force casting mask to UInt32 to ensure correct datatype.
# Resampling image and mask
# Where resampled spacing is set to 0, set it to the original spacing (mask)
# Checking ROI validity
# Checking if label 1 is persent in the mask
# Comparing physical space of bounding box to physical space of image
# ROI bounds (image coordinate space): ((-0.5000000000000002, -0.500000000000006, -0.5), (55.5, 70.5, 21.5))
# ROI valid, calculating resampling grid
# Comparing resampled spacing to original spacing (image
# Applying resampling from spacing [0.919 0.919 2.   ] and size [56 71 22] to spacing [1. 1. 1.] and size [52, 66, 44]
# Resampling image
# Resampling mask
# Checking mask with label 1
# Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# Image and Mask loaded and valid, starting extraction
# Cropping to size [51 65 44]
# Computing shape
# Initializing feature class
# Padding the mask with 0s
# Pre-calculate Volume, Surface Area and Eigenvalues
# Starting radiomic feature extraction...
# Shape feature class initialized
# Calculating features
# Creating image type iterator
# Adding image type "Original" with custom settings: {}
# Adding image type "Square" with custom settings: {}
# Adding image type "SquareRoot" with custom settings: {}
# Adding image type "Logarithm" with custom settings: {}
# Adding image type "Exponential" with custom settings: {}
# Adding image type "Gradient" with custom settings: {}
# Extracting features
# Yielding original image
# Calculating features for original image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 319, 319, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 319, 16, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 319, 68)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 319, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating features
# Yielding square image
# Calculating features for square image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 136, 136, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 136, 34, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 136, 14)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 136, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating features
# Yielding squareroot image
# Calculating features for squareroot image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 726, 726, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 726, 6, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 726, 22)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 726, 12)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating features
# Yielding logarithm image
# Calculating features for logarithm image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 1034, 1034, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 1034, 4, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 1034, 12)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 1034, 6)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating features
# Yielding exponential image
# Calculating features for exponential image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 35, 35, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 35, 34, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 35, 4)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 35, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating features
# Calculating features for gradient image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
# ...
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 255, 23, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 255, 42)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 255, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating features
# Features extracted

# %%
import pandas as pd
pd.DataFrame.from_dict(radiomicFeatures, orient="index").transpose()

# %%
for (key, val) in six.iteritems(radiomicFeatures):
  print('  ', key, ':', val)

# %% [markdown]
# # Use singleRadiomicFeatureExtraction function

# %%
from readii.feature_extraction import singleRadiomicFeatureExtraction 
from func_timeout import func_timeout, FunctionTimedOut

try:
    pyradiomicsParamFilePath = "/Users/katyscott/Documents/readii/src/readii/data/default_pyradiomics.yaml"
    radiomicFeatures = func_timeout(timeout = 1800, func = singleRadiomicFeatureExtraction, args = (ctImage, roiMask, pyradiomicsParamFilePath, "randomized_roi", 10))
except FunctionTimedOut:
    print("Default radiomics features took too long to run. Running without wavelet filter.")
    pyradiomicsParamFilePath = "/Users/katyscott/Documents/HNC Project/scripts/hnc_readii-2-roqc/config/no_wavelet_pyradiomics.yaml"
    radiomicFeatures = singleRadiomicFeatureExtraction(ctImage, roiMask, pyradiomicsParamFilePath, None, 10)
except Exception as e:
    print(e)
# Out:
# Checking mask with label 1
# Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# Generating  randomized_roi negative control for CT.
# Cropping to size [56 71 22]
# Loading parameter file /Users/katyscott/Documents/readii/src/readii/data/default_pyradiomics.yaml
# Parameters parsed, input is valid.
# Applying settings
# Enabled image types: {'Original': {}, 'Wavelet': {}, 'Square': {}, 'SquareRoot': {}, 'Logarithm': {}, 'Exponential': {}, 'Gradient': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Settings: {'binWidth': 25, 'resampledPixelSpacing': [1.0, 1.0, 1.0]}
# Calculating features with label: 1
# Enabled images types: {'Original': {}, 'Wavelet': {}, 'Square': {}, 'SquareRoot': {}, 'Logarithm': {}, 'Exponential': {}, 'Gradient': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.0, 1.0, 1.0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25}
# Loading image and mask
# Force casting mask to UInt32 to ensure correct datatype.
# Resampling image and mask
# Where resampled spacing is set to 0, set it to the original spacing (mask)
# Checking ROI validity
# Checking if label 1 is persent in the mask
# Comparing physical space of bounding box to physical space of image
# ROI bounds (image coordinate space): ((-0.5000000000000002, -0.500000000000006, -0.5), (55.5, 70.5, 21.5))
# ROI valid, calculating resampling grid
# Comparing resampled spacing to original spacing (image
# Applying resampling from spacing [0.919 0.919 2.   ] and size [56 71 22] to spacing [1. 1. 1.] and size [52, 66, 44]
# Resampling image
# Resampling mask
# Checking mask with label 1
# Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# Image and Mask loaded and valid, starting extraction
# Cropping to size [51 65 44]
# Computing shape
# Initializing feature class
# Padding the mask with 0s
# Pre-calculate Volume, Surface Area and Eigenvalues
# Shape feature class initialized
# Calculating features
# Creating image type iterator
# Adding image type "Original" with custom settings: {}
# Adding image type "Wavelet" with custom settings: {}
# Adding image type "Square" with custom settings: {}
# Adding image type "SquareRoot" with custom settings: {}
# Adding image type "Logarithm" with custom settings: {}
# Adding image type "Exponential" with custom settings: {}
# Adding image type "Gradient" with custom settings: {}
# Extracting features
# Yielding original image
# Calculating features for original image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1740 bins for bin width 25 with edges: [-10700 -10675 -10650 ...  32750  32775  32800])
# Starting radiomic feature extraction...
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1740 bins for bin width 25 with edges: [-10700 -10675 -10650 ...  32750  32775  32800])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 1546, 1546, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1740 bins for bin width 25 with edges: [-10700 -10675 -10650 ...  32750  32775  32800])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 1546, 2, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1740 bins for bin width 25 with edges: [-10700 -10675 -10650 ...  32750  32775  32800])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 1546, 4)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1740 bins for bin width 25 with edges: [-10700 -10675 -10650 ...  32750  32775  32800])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 1546, 4)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1740 bins for bin width 25 with edges: [-10700 -10675 -10650 ...  32750  32775  32800])
# Calculating features
# Generating Wavelet images
# Computing Wavelet LLH
# Yielding wavelet-LLH image
# Calculating features for wavelet-LLH image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1517 bins for bin width 25 with edges: [-18200. -18175. -18150. ...  19675.  19700.  19725.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1517 bins for bin width 25 with edges: [-18200. -18175. -18150. ...  19675.  19700.  19725.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 1041, 1041, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1517 bins for bin width 25 with edges: [-18200. -18175. -18150. ...  19675.  19700.  19725.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 1041, 3, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1517 bins for bin width 25 with edges: [-18200. -18175. -18150. ...  19675.  19700.  19725.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 1041, 3)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1517 bins for bin width 25 with edges: [-18200. -18175. -18150. ...  19675.  19700.  19725.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 1041, 3)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1517 bins for bin width 25 with edges: [-18200. -18175. -18150. ...  19675.  19700.  19725.])
# Calculating features
# Computing Wavelet LHL
# Yielding wavelet-LHL image
# Calculating features for wavelet-LHL image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3265 bins for bin width 25 with edges: [-43900. -43875. -43850. ...  37675.  37700.  37725.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3265 bins for bin width 25 with edges: [-43900. -43875. -43850. ...  37675.  37700.  37725.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 2138, 2138, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3265 bins for bin width 25 with edges: [-43900. -43875. -43850. ...  37675.  37700.  37725.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 2138, 2, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3265 bins for bin width 25 with edges: [-43900. -43875. -43850. ...  37675.  37700.  37725.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 2138, 3)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3265 bins for bin width 25 with edges: [-43900. -43875. -43850. ...  37675.  37700.  37725.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 2138, 3)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3265 bins for bin width 25 with edges: [-43900. -43875. -43850. ...  37675.  37700.  37725.])
# Calculating features
# Computing Wavelet LHH
# Yielding wavelet-LHH image
# Calculating features for wavelet-LHH image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1094 bins for bin width 25 with edges: [-13475. -13450. -13425. ...  13825.  13850.  13875.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1094 bins for bin width 25 with edges: [-13475. -13450. -13425. ...  13825.  13850.  13875.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 827, 827, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1094 bins for bin width 25 with edges: [-13475. -13450. -13425. ...  13825.  13850.  13875.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 827, 3, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1094 bins for bin width 25 with edges: [-13475. -13450. -13425. ...  13825.  13850.  13875.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 827, 4)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1094 bins for bin width 25 with edges: [-13475. -13450. -13425. ...  13825.  13850.  13875.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 827, 4)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1094 bins for bin width 25 with edges: [-13475. -13450. -13425. ...  13825.  13850.  13875.])
# Calculating features
# Computing Wavelet HLL
# Yielding wavelet-HLL image
# Calculating features for wavelet-HLL image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3542 bins for bin width 25 with edges: [-46175. -46150. -46125. ...  42325.  42350.  42375.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 3542 bins for bin width 25 with edges: [-46175. -46150. -46125. ...  42325.  42350.  42375.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 2204, 2204, 13)
# Calculating features
# Checking mask with label 1
# Calculating bounding box
# Default radiomics features took too long to run. Running without wavelet filter.
# Checking minimum number of dimensions requirements (2)
# Cropping to size [56 71 22]
# Loading parameter file /Users/katyscott/Documents/HNC Project/scripts/hnc_readii-2-roqc/config/no_wavelet_pyradiomics.yaml
# Parameters parsed, input is valid.
# Applying settings
# Enabled image types: {'Original': {}, 'Square': {}, 'SquareRoot': {}, 'Logarithm': {}, 'Exponential': {}, 'Gradient': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Settings: {'binWidth': 25, 'resampledPixelSpacing': [1.0, 1.0, 1.0]}
# Calculating features with label: 1
# Enabled images types: {'Original': {}, 'Square': {}, 'SquareRoot': {}, 'Logarithm': {}, 'Exponential': {}, 'Gradient': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.0, 1.0, 1.0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25}
# Loading image and mask
# Force casting mask to UInt32 to ensure correct datatype.
# Resampling image and mask
# Where resampled spacing is set to 0, set it to the original spacing (mask)
# Checking ROI validity
# Checking if label 1 is persent in the mask
# Comparing physical space of bounding box to physical space of image
# ROI bounds (image coordinate space): ((-0.5000000000000002, -0.500000000000006, -0.5), (55.5, 70.5, 21.5))
# ROI valid, calculating resampling grid
# Comparing resampled spacing to original spacing (image
# Applying resampling from spacing [0.919 0.919 2.   ] and size [56 71 22] to spacing [1. 1. 1.] and size [52, 66, 44]
# Resampling image
# Resampling mask
# Checking mask with label 1
# Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# Image and Mask loaded and valid, starting extraction
# Cropping to size [51 65 44]
# Computing shape
# Initializing feature class
# Padding the mask with 0s
# Pre-calculate Volume, Surface Area and Eigenvalues
# Starting radiomic feature extraction...
# Shape feature class initialized
# Calculating features
# Creating image type iterator
# Adding image type "Original" with custom settings: {}
# Adding image type "Square" with custom settings: {}
# Adding image type "SquareRoot" with custom settings: {}
# Adding image type "Logarithm" with custom settings: {}
# Adding image type "Exponential" with custom settings: {}
# Adding image type "Gradient" with custom settings: {}
# Extracting features
# Yielding original image
# Calculating features for original image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 319, 319, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 319, 16, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 319, 68)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 319, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1379 bins for bin width 25 with edges: [-3625 -3600 -3575 ... 30800 30825 30850])
# Calculating features
# Yielding square image
# Calculating features for square image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 136, 136, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 136, 34, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 136, 14)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 136, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1160 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.8950e+04 2.8975e+04 2.9000e+04])
# Calculating features
# Yielding squareroot image
# Calculating features for squareroot image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 726, 726, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 726, 6, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 726, 22)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 726, 12)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1707 bins for bin width 25 with edges: [-10875. -10850. -10825. ...  31750.  31775.  31800.])
# Calculating features
# Yielding logarithm image
# Calculating features for logarithm image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 1034, 1034, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 1034, 4, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 1034, 12)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 1034, 6)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2337 bins for bin width 25 with edges: [-25825. -25800. -25775. ...  32550.  32575.  32600.])
# Calculating features
# Yielding exponential image
# Calculating features for exponential image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 35, 35, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 35, 34, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075. 15100. 15125. 15150. 15175. 15200. 15225.
#  15250. 15275. 15300. 15325. 15350. 15375. 15400. 15425. 15450. 15475.
#  15500. 15525. 15550. 15575. 15600. 15625. 15650. 15675. 15700. 15725.
#  15750. 15775. 15800. 15825. 15850. 15875. 15900. 15925. 15950. 15975.
#  16000. 16025. 16050. 16075. 16100. 16125. 16150. 16175. 16200. 16225.
#  16250. 16275. 16300. 16325. 16350. 16375. 16400. 16425. 16450. 16475.
#  16500. 16525. 16550. 16575. 16600. 16625. 16650. 16675. 16700. 16725.
#  16750. 16775. 16800. 16825. 16850. 16875. 16900. 16925. 16950. 16975.
#  17000. 17025. 17050. 17075. 17100. 17125. 17150. 17175. 17200. 17225.
#  17250. 17275. 17300. 17325. 17350. 17375. 17400. 17425. 17450. 17475.
#  17500. 17525. 17550. 17575. 17600. 17625. 17650.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 35, 4)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 706 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
# ...
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 255, 23, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 255, 42)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 255, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 603 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900. 14925. 14950. 14975.
#  15000. 15025. 15050. 15075.])
# Calculating features
# Features extracted

# %%
import pandas as pd
pd.DataFrame.from_dict(radiomicFeatures, orient="index").transpose()
# Out:
#   diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# 0                         v3.0.1a3                     1.26.4
#
#   diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# 0                          2.3.1                          1.5.0
#
#   diagnostics_Versions_Python  \
# 0                      3.9.18
#
#                   diagnostics_Configuration_Settings  \
# 0  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#          diagnostics_Configuration_EnabledImageTypes  \
# 0  {'Original': {}, 'Square': {}, 'SquareRoot': {...
#
#             diagnostics_Image-original_Hash  \
# 0  78e99f434f61bce26aaff1d2221b675ac1efd4c3
#
#   diagnostics_Image-original_Dimensionality  \
# 0                                        3D
#
#   diagnostics_Image-original_Spacing  ...  \
# 0                (0.919, 0.919, 2.0)  ...
#
#   gradient_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                138.03149063522696
#
#   gradient_gldm_LowGrayLevelEmphasis gradient_gldm_SmallDependenceEmphasis  \
# 0                0.46473757325088433                   0.11277028674550117
#
#   gradient_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                 1026.9517314366883
#
#   gradient_gldm_SmallDependenceLowGrayLevelEmphasis gradient_ngtdm_Busyness  \
# 0                             0.0074465670195857665      1.0214470507517626
#
#   gradient_ngtdm_Coarseness gradient_ngtdm_Complexity gradient_ngtdm_Contrast  \
# 0     0.0004959373676274749         138342.4747045337     0.06420642868525576
#
#   gradient_ngtdm_Strength
# 0       834.8086224396645
#
# [1 rows x 609 columns]

# %%
from radiomics import featureextractor
import yaml

pyradiomicsParamFilePath = "/Users/katyscott/Documents/readii/src/readii/data/default_pyradiomics.yaml"

with open(pyradiomicsParamFilePath, 'r') as file:
    data = yaml.safe_load(file)

# imageTypes = data.pop('imageType')
# del imageTypes['Wavelet']
# data['imageType'] = imageTypes

# featureExtractor = featureextractor.RadiomicsFeatureExtractor(data)

# %%
del data['imageType']['Wavelet']

# %%
data
# Out:
# {'imageType': {'Original': {},
#   'Square': {},
#   'SquareRoot': {},
#   'Logarithm': {},
#   'Exponential': {},
#   'Gradient': {}},
#  'featureClass': {'shape': None,
#   'firstorder': None,
#   'glcm': None,
#   'glrlm': None,
#   'glszm': None,
#   'gldm': None,
#   'ngtdm': None},
#  'setting': {'binWidth': 25, 'resampledPixelSpacing': [1.0, 1.0, 1.0]}}

# %%
idFeatureVector = featureExtractor.execute(ctImage, roiMask, label=segmentationLabel)
# Out:
# Calculating features with label: 1
# Enabled images types: {'Original': {}, 'Square': {}, 'SquareRoot': {}, 'Logarithm': {}, 'Exponential': {}, 'Gradient': {}}
# Enabled features: {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}
# Current settings: {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': False, 'normalizeScale': 1, 'removeOutliers': None, 'resampledPixelSpacing': [1.0, 1.0, 1.0], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 25}
# Loading image and mask
# Force casting mask to UInt32 to ensure correct datatype.
# Resampling image and mask
# Where resampled spacing is set to 0, set it to the original spacing (mask)
# Checking ROI validity
# Checking if label 1 is persent in the mask
# Comparing physical space of bounding box to physical space of image
# ROI bounds (image coordinate space): ((260.5, 123.50000000000001, 101.5), (316.5, 194.50000000000003, 123.5))
# ROI valid, calculating resampling grid
# Comparing resampled spacing to original spacing (image
# Applying resampling from spacing [0.919 0.919 2.   ] and size [512 512 178] to spacing [1. 1. 1.] and size [63, 77, 55]
# Resampling image
# Resampling mask
# Checking mask with label 1
# Calculating bounding box
# Checking minimum number of dimensions requirements (2)
# Image and Mask loaded and valid, starting extraction
# Cropping to size [51 65 44]
# Computing shape
# Initializing feature class
# Padding the mask with 0s
# Pre-calculate Volume, Surface Area and Eigenvalues
# Shape feature class initialized
# Calculating features
# Creating image type iterator
# Adding image type "Original" with custom settings: {}
# Adding image type "Square" with custom settings: {}
# Adding image type "SquareRoot" with custom settings: {}
# Adding image type "Logarithm" with custom settings: {}
# Adding image type "Exponential" with custom settings: {}
# Adding image type "Gradient" with custom settings: {}
# Extracting features
# Yielding original image
# Calculating features for original image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1325 bins for bin width 25 with edges: [-3425 -3400 -3375 ... 29650 29675 29700])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1325 bins for bin width 25 with edges: [-3425 -3400 -3375 ... 29650 29675 29700])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 321, 321, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1325 bins for bin width 25 with edges: [-3425 -3400 -3375 ... 29650 29675 29700])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 321, 16, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1325 bins for bin width 25 with edges: [-3425 -3400 -3375 ... 29650 29675 29700])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 321, 72)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1325 bins for bin width 25 with edges: [-3425 -3400 -3375 ... 29650 29675 29700])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 321, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1325 bins for bin width 25 with edges: [-3425 -3400 -3375 ... 29650 29675 29700])
# Calculating features
# Yielding square image
# Calculating features for square image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1076 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.6850e+04 2.6875e+04 2.6900e+04])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1076 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.6850e+04 2.6875e+04 2.6900e+04])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 128, 128, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1076 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.6850e+04 2.6875e+04 2.6900e+04])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 128, 34, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1076 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.6850e+04 2.6875e+04 2.6900e+04])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 128, 14)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1076 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.6850e+04 2.6875e+04 2.6900e+04])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 128, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1076 bins for bin width 25 with edges: [0.0000e+00 2.5000e+01 5.0000e+01 ... 2.6850e+04 2.6875e+04 2.6900e+04])
# Calculating features
# Yielding squareroot image
# Calculating features for squareroot image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1673 bins for bin width 25 with edges: [-10600. -10575. -10550. ...  31175.  31200.  31225.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1673 bins for bin width 25 with edges: [-10600. -10575. -10550. ...  31175.  31200.  31225.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 714, 714, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1673 bins for bin width 25 with edges: [-10600. -10575. -10550. ...  31175.  31200.  31225.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 714, 5, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1673 bins for bin width 25 with edges: [-10600. -10575. -10550. ...  31175.  31200.  31225.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 714, 24)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1673 bins for bin width 25 with edges: [-10600. -10575. -10550. ...  31175.  31200.  31225.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 714, 10)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 1673 bins for bin width 25 with edges: [-10600. -10575. -10550. ...  31175.  31200.  31225.])
# Calculating features
# Yielding logarithm image
# Calculating features for logarithm image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2326 bins for bin width 25 with edges: [-25650. -25625. -25600. ...  32450.  32475.  32500.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2326 bins for bin width 25 with edges: [-25650. -25625. -25600. ...  32450.  32475.  32500.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 1030, 1030, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2326 bins for bin width 25 with edges: [-25650. -25625. -25600. ...  32450.  32475.  32500.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 1030, 4, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2326 bins for bin width 25 with edges: [-25650. -25625. -25600. ...  32450.  32475.  32500.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 1030, 10)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2326 bins for bin width 25 with edges: [-25650. -25625. -25600. ...  32450.  32475.  32500.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 1030, 6)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 2326 bins for bin width 25 with edges: [-25650. -25625. -25600. ...  32450.  32475.  32500.])
# Calculating features
# Yielding exponential image
# Calculating features for exponential image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 491 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 491 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 37, 37, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 491 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 37, 34, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 491 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 37, 4)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 491 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 37, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 491 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275.])
# Calculating features
# Calculating features for gradient image
# Cropping to size [51 65 44]
# Computing firstorder
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 596 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900.])
# First order feature class initialized
# Calculating features
# Computing glcm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 596 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900.])
# Calculating GLCM matrix in C
# Process calculated matrix
# Create symmetrical matrix
# No empty angles
# Calculating GLCM coefficients
# GLCM feature class initialized, calculated GLCM with shape (1, 244, 244, 13)
# Calculating features
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# Computing glrlm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 596 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900.])
# Calculating GLRLM matrix in C
# Process calculated matrix
# No empty angles
# Calculating GLRLM coefficients
# GLRLM feature class initialized, calculated GLRLM with shape (1, 244, 23, 13)
# Calculating features
# Computing glszm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 596 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900.])
# Calculating GLSZM matrix in C
# Calculating GLSZM coefficients
# GLSZM feature class initialized, calculated GLSZM with shape (1, 244, 42)
# Calculating features
# Computing gldm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 596 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900.])
# Calculating GLDM matrix in C
# Feature class initialized, calculated GLDM with shape (1, 244, 27)
# Calculating features
# Computing ngtdm
# Initializing feature class
# Discretizing gray levels inside ROI
# Calculated 596 bins for bin width 25 with edges: [    0.    25.    50.    75.   100.   125.   150.   175.   200.   225.
#    250.   275.   300.   325.   350.   375.   400.   425.   450.   475.
#    500.   525.   550.   575.   600.   625.   650.   675.   700.   725.
#    750.   775.   800.   825.   850.   875.   900.   925.   950.   975.
#   1000.  1025.  1050.  1075.  1100.  1125.  1150.  1175.  1200.  1225.
#   1250.  1275.  1300.  1325.  1350.  1375.  1400.  1425.  1450.  1475.
#   1500.  1525.  1550.  1575.  1600.  1625.  1650.  1675.  1700.  1725.
#   1750.  1775.  1800.  1825.  1850.  1875.  1900.  1925.  1950.  1975.
#   2000.  2025.  2050.  2075.  2100.  2125.  2150.  2175.  2200.  2225.
#   2250.  2275.  2300.  2325.  2350.  2375.  2400.  2425.  2450.  2475.
#   2500.  2525.  2550.  2575.  2600.  2625.  2650.  2675.  2700.  2725.
#   2750.  2775.  2800.  2825.  2850.  2875.  2900.  2925.  2950.  2975.
#   3000.  3025.  3050.  3075.  3100.  3125.  3150.  3175.  3200.  3225.
#   3250.  3275.  3300.  3325.  3350.  3375.  3400.  3425.  3450.  3475.
#   3500.  3525.  3550.  3575.  3600.  3625.  3650.  3675.  3700.  3725.
#   3750.  3775.  3800.  3825.  3850.  3875.  3900.  3925.  3950.  3975.
#   4000.  4025.  4050.  4075.  4100.  4125.  4150.  4175.  4200.  4225.
#   4250.  4275.  4300.  4325.  4350.  4375.  4400.  4425.  4450.  4475.
#   4500.  4525.  4550.  4575.  4600.  4625.  4650.  4675.  4700.  4725.
#   4750.  4775.  4800.  4825.  4850.  4875.  4900.  4925.  4950.  4975.
#   5000.  5025.  5050.  5075.  5100.  5125.  5150.  5175.  5200.  5225.
#   5250.  5275.  5300.  5325.  5350.  5375.  5400.  5425.  5450.  5475.
#   5500.  5525.  5550.  5575.  5600.  5625.  5650.  5675.  5700.  5725.
#   5750.  5775.  5800.  5825.  5850.  5875.  5900.  5925.  5950.  5975.
#   6000.  6025.  6050.  6075.  6100.  6125.  6150.  6175.  6200.  6225.
#   6250.  6275.  6300.  6325.  6350.  6375.  6400.  6425.  6450.  6475.
#   6500.  6525.  6550.  6575.  6600.  6625.  6650.  6675.  6700.  6725.
#   6750.  6775.  6800.  6825.  6850.  6875.  6900.  6925.  6950.  6975.
#   7000.  7025.  7050.  7075.  7100.  7125.  7150.  7175.  7200.  7225.
#   7250.  7275.  7300.  7325.  7350.  7375.  7400.  7425.  7450.  7475.
#   7500.  7525.  7550.  7575.  7600.  7625.  7650.  7675.  7700.  7725.
#   7750.  7775.  7800.  7825.  7850.  7875.  7900.  7925.  7950.  7975.
#   8000.  8025.  8050.  8075.  8100.  8125.  8150.  8175.  8200.  8225.
#   8250.  8275.  8300.  8325.  8350.  8375.  8400.  8425.  8450.  8475.
#   8500.  8525.  8550.  8575.  8600.  8625.  8650.  8675.  8700.  8725.
#   8750.  8775.  8800.  8825.  8850.  8875.  8900.  8925.  8950.  8975.
#   9000.  9025.  9050.  9075.  9100.  9125.  9150.  9175.  9200.  9225.
#   9250.  9275.  9300.  9325.  9350.  9375.  9400.  9425.  9450.  9475.
#   9500.  9525.  9550.  9575.  9600.  9625.  9650.  9675.  9700.  9725.
#   9750.  9775.  9800.  9825.  9850.  9875.  9900.  9925.  9950.  9975.
#  10000. 10025. 10050. 10075. 10100. 10125. 10150. 10175. 10200. 10225.
#  10250. 10275. 10300. 10325. 10350. 10375. 10400. 10425. 10450. 10475.
#  10500. 10525. 10550. 10575. 10600. 10625. 10650. 10675. 10700. 10725.
#  10750. 10775. 10800. 10825. 10850. 10875. 10900. 10925. 10950. 10975.
#  11000. 11025. 11050. 11075. 11100. 11125. 11150. 11175. 11200. 11225.
#  11250. 11275. 11300. 11325. 11350. 11375. 11400. 11425. 11450. 11475.
#  11500. 11525. 11550. 11575. 11600. 11625. 11650. 11675. 11700. 11725.
#  11750. 11775. 11800. 11825. 11850. 11875. 11900. 11925. 11950. 11975.
#  12000. 12025. 12050. 12075. 12100. 12125. 12150. 12175. 12200. 12225.
#  12250. 12275. 12300. 12325. 12350. 12375. 12400. 12425. 12450. 12475.
#  12500. 12525. 12550. 12575. 12600. 12625. 12650. 12675. 12700. 12725.
#  12750. 12775. 12800. 12825. 12850. 12875. 12900. 12925. 12950. 12975.
#  13000. 13025. 13050. 13075. 13100. 13125. 13150. 13175. 13200. 13225.
#  13250. 13275. 13300. 13325. 13350. 13375. 13400. 13425. 13450. 13475.
#  13500. 13525. 13550. 13575. 13600. 13625. 13650. 13675. 13700. 13725.
#  13750. 13775. 13800. 13825. 13850. 13875. 13900. 13925. 13950. 13975.
#  14000. 14025. 14050. 14075. 14100. 14125. 14150. 14175. 14200. 14225.
#  14250. 14275. 14300. 14325. 14350. 14375. 14400. 14425. 14450. 14475.
#  14500. 14525. 14550. 14575. 14600. 14625. 14650. 14675. 14700. 14725.
#  14750. 14775. 14800. 14825. 14850. 14875. 14900.])
# Calculating features
# Features extracted
